# %%
import pandas as pd

df = pd.read_csv("hf://datasets/maharshipandya/spotify-tracks-dataset/dataset.csv")

# %%
df.to_csv("dataset.csv", index=False)

# %%
df.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
import pandas as pd 

df=pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df['duration_minutes'] = df['duration_ms'] / 60000

# %%
df['explicit'] = df['explicit'].map({1: 'Yes', 0: 'No'})
df['mode'] = df['mode'].map({1: 'Major', 0: 'Minor'})

# %%
df = df.drop_duplicates(subset=['track_id'])

# %%
unique_genres = df['track_genre'].unique()
print("Genres uniques :", unique_genres)
# Out:
# Genres uniques : ['acoustic' 'afrobeat' 'alt-rock' 'alternative' 'ambient' 'anime'
#  'black-metal' 'bluegrass' 'blues' 'brazil' 'breakbeat' 'british'
#  'cantopop' 'chicago-house' 'children' 'chill' 'classical' 'club' 'comedy'
#  'country' 'dance' 'dancehall' 'death-metal' 'deep-house' 'detroit-techno'
#  'disco' 'disney' 'drum-and-bass' 'dub' 'dubstep' 'edm' 'electro'
#  'electronic' 'emo' 'folk' 'forro' 'french' 'funk' 'garage' 'german'
#  'gospel' 'goth' 'grindcore' 'groove' 'grunge' 'guitar' 'happy'
#  'hard-rock' 'hardcore' 'hardstyle' 'heavy-metal' 'hip-hop' 'honky-tonk'
#  'house' 'idm' 'indian' 'indie-pop' 'indie' 'industrial' 'iranian'
#  'j-dance' 'j-idol' 'j-pop' 'j-rock' 'jazz' 'k-pop' 'kids' 'latin'
#  'latino' 'malay' 'mandopop' 'metal' 'metalcore' 'minimal-techno' 'mpb'
#  'new-age' 'opera' 'pagode' 'party' 'piano' 'pop-film' 'pop' 'power-pop'
#  'progressive-house' 'psych-rock' 'punk-rock' 'punk' 'r-n-b' 'reggae'
# ...

# %%
genre_mapping = {
    'alt-rock': 'Rock', 'alternative': 'Rock', 'hard-rock': 'Rock', 'punk': 'Rock', 
    'punk-rock': 'Rock', 'psych-rock': 'Rock', 'rock-n-roll': 'Rock', 'rock': 'Rock', 
    'grunge': 'Rock', 'garage': 'Rock', 'guitar': 'Rock', 'emo': 'Rock', 'metal': 'Rock',
    'metalcore': 'Rock', 'heavy-metal': 'Rock', 'black-metal': 'Rock', 'death-metal': 'Rock', 
    'hardcore': 'Rock', 'grindcore': 'Rock',
    'pop': 'Pop', 'indie-pop': 'Pop', 'power-pop': 'Pop', 'synth-pop': 'Pop', 
    'pop-film': 'Pop', 'j-pop': 'Pop', 'k-pop': 'Pop', 'british': 'Pop', 
    'cantopop': 'Pop', 'mandopop': 'Pop',
    'electronic': 'Electronic/Dance', 'edm': 'Electronic/Dance', 'electro': 'Electronic/Dance', 
    'techno': 'Electronic/Dance', 'house': 'Electronic/Dance', 'deep-house': 'Electronic/Dance', 
    'progressive-house': 'Electronic/Dance', 'club': 'Electronic/Dance', 'chicago-house': 'Electronic/Dance', 
    'detroit-techno': 'Electronic/Dance', 'trance': 'Electronic/Dance', 'drum-and-bass': 'Electronic/Dance', 
    'dubstep': 'Electronic/Dance', 'breakbeat': 'Electronic/Dance', 'idm': 'Electronic/Dance', 
    'minimal-techno': 'Electronic/Dance',
    'hip-hop': 'Hip-Hop/Rap', 'rap': 'Hip-Hop/Rap', 'trap': 'Hip-Hop/Rap',
    'jazz': 'Jazz/Blues', 'blues': 'Jazz/Blues', 'bluegrass': 'Jazz/Blues', 'soul': 'Jazz/Blues', 
    'funk': 'Jazz/Blues', 'groove': 'Jazz/Blues', 'gospel': 'Jazz/Blues',
    'classical': 'Classical/Instrumental', 'opera': 'Classical/Instrumental', 'piano': 'Classical/Instrumental', 
    'ambient': 'Classical/Instrumental', 'study': 'Classical/Instrumental', 'new-age': 'Classical/Instrumental', 
    'sleep': 'Classical/Instrumental', 'singer-songwriter': 'Classical/Instrumental',
    'latin': 'World Music', 'latino': 'World Music', 'salsa': 'World Music', 'samba': 'World Music', 
    'pagode': 'World Music', 'sertanejo': 'World Music', 'brazil': 'World Music', 'forro': 'World Music', 
    'mpb': 'World Music', 'french': 'World Music', 'german': 'World Music', 'swedish': 'World Music', 
    'turkish': 'World Music', 'malay': 'World Music', 'iranian': 'World Music', 'indian': 'World Music', 
    'world-music': 'World Music',
    'reggae': 'Reggae/Dub', 'reggaeton': 'Reggae/Dub', 'dub': 'Reggae/Dub', 'dancehall': 'Reggae/Dub',
    'children': 'Children/Comedy', 'kids': 'Children/Comedy', 'comedy': 'Children/Comedy', 
    'disney': 'Children/Comedy', 'show-tunes': 'Children/Comedy',
    'anime': 'Anime/J-Music', 'j-idol': 'Anime/J-Music', 'j-rock': 'Anime/J-Music', 
    'j-dance': 'Anime/J-Music',
    'country': 'Country/Folk', 'honky-tonk': 'Country/Folk', 'folk': 'Country/Folk', 'acoustic': 'Country/Folk',
    'party': 'Party/Happy', 'happy': 'Party/Happy', 'dance': 'Party/Happy', 'romance': 'Party/Happy', 
    'chill': 'Party/Happy',
    'alternative': 'Alternative', 'indie': 'Alternative', 'industrial': 'Alternative',
    'tango': 'Tango', 
    'spanish': 'World Music', 'rockabilly': 'Rock'
}

# %%
df['main_genre'] = df['track_genre'].map(genre_mapping)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculer la popularité totale par genre principal
main_genre_popularity = df.groupby('main_genre')['popularity'].mean().sort_values(ascending=False)

# Créer un bar plot pour les genres principaux
plt.figure(figsize=(12, 6))
sns.barplot(x=main_genre_popularity.index, y=main_genre_popularity.values, palette='viridis')
plt.title('Popularity per genre', fontsize=16)
plt.xlabel('Genre', fontsize=14)
plt.ylabel('Popularity', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Aycha\AppData\Local\Temp\ipykernel_21300\1105645438.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=main_genre_popularity.index, y=main_genre_popularity.values, palette='viridis')

# %%
df.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre', 'duration_minutes',
#        'main_genre'],
#       dtype='object')

# %%
df.to_csv('dataset.csv', index=False)
